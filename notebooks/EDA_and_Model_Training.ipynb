# %% [markdown]
# # Green Route ML Pipeline
# EDA, preprocessing, model training.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('../data/routes_dataset.csv')
df.head()

# %%
# Example emission factors
emission_factors = {'bike':0.02,'car':0.12,'bus':0.05,'train':0.03,'flight':0.25}
for k,v in emission_factors.items():
    df[k+'_emission'] = df['distance_km']*v
df.head()
